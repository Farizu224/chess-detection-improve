# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="jDh0EVC94eG10ly0jiAY")
project = rf.workspace("kosan-hendra").project("chess_detection-uzejh")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install ultralytics

from ultralytics import YOLO

# Load model YOLOv8 (bisa pilih nano, small, medium, large)
model = YOLO("yolov8n.pt")  # 'n' = nano (ringan)

# Train model
model.train(
    data="/content/chess_detection-2/data.yaml",
    epochs=100,
    patience=20,
    imgsz=720,
    batch=16,
    device=0,
    project="/content/drive/MyDrive/chess_detection",
    name="yolov8_chess_v3"
)
# Out:
# ...
# Ultralytics 8.3.185 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
